# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:**
#
# ### California has more billionaires than any other state and yet education system is ranked lowly at 41 out of 51 states ([*source*](https://wallethub.com/edu/e/states-with-the-best-schools/5335)). This projects aims to analyse relationships between key demographic indicators and performance of standardized tests, and to identify areas of improvements in different counties across California.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:**
#
# The racial proportions within each county in the state of California differs and this may lead to varying opportunities given to different racial communities.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`CA_income_data_2019.csv`](./data/CA_income_data_2019.csv): 2019 income data by County
# * [`acs2017_county_data.csv`](./data/acs2017_county_data.csv): 2017 demographic data by County

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean_value(num_list:list):
    res = 0
    for num in num_list:
        res += num
    return res/(len(num_list))

mean_value([1,2,4,5,7,2,3,43])
# Out:
# 8.375

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(num_list:list):
    val = 0
    for num in num_list:   
        val += (num - mean_value(num_list))**2
    return (val/len(num_list))**0.5

std_dev([1,2,4,5,7,2,3,43])
# Out:
# 13.209253385411305

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def data_cleaning(string:str):
    string_num = string.replace("%","")
    return float(string_num) / 100

data_cleaning("30.5%")
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Import libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('fivethirtyeight')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
sns.set(font_scale = 0.8)


# Import datasets:
df_act = pd.read_csv('../data/act_2019_ca.csv')
df_sat = pd.read_csv('../data/sat_2019_ca.csv')
df_income = pd.read_csv('../data/CA_income_data_2019.csv')
df_demograph = pd.read_csv('../data/acs2017_county_data.csv')


# Data cleaning df_income (external datasets)
# Answers to questions 2 to 8 below:
# rename columns
df_income.columns = ['year', 'period', 'county', 'per_capita_income']
# standardize county convention to match that of df_act 
df_income.county = df_income.county.str.replace(" County","")
# drop unnecessary columns
df_income.drop(columns=['year', 'period'], inplace=True)
# check for addtional scharacters that are preventing conversion to float type and remove them
df_income["per_capita_income"] = df_income["per_capita_income"].map(lambda x: x.replace("$",""))
df_income["per_capita_income"] = df_income["per_capita_income"].map(lambda x: x.replace(",",""))
# change per_capita_income column to float type
df_income["per_capita_income"] = df_income["per_capita_income"].astype(float)

# Data cleaning df_demograph (external datasets)
df_demograph = df_demograph[df_demograph["State"] == "California"]
df_demograph = df_demograph.iloc[:,[2,4,5,6,7,8,9,10,11,13,15,17,36]]
df_demograph["County"] = df_demograph.loc[:,"County"].map(lambda x: x.replace(" County", ""))
df_demograph.rename(columns={"County": "county"}, inplace=True)
df_demograph["minority"] = 100-df_demograph["White"]

# %% [markdown]
# # Other Functions

# %%
# create function to remove outliers based on mean + 3 std dev in income data:
def remove_outliers(df, column, sign):
    mean = df.describe().at["mean", column]
    std = df.describe().at["std", column]
    
    if sign == "plus":
        print(f"outliers are: {df[df[column] > (mean+3*std)].loc[:]}")
        df.drop(df[df[column] > (mean+3*std)].index, inplace=True)
#         print(df.sort_values('per_capita_income', ascending=False))
        return df
    
    elif sign =="minus":
        print(f"outliers are: {df[df[column] < (mean-3*std)].loc[:]}")
        df.drop(df[df[column] < (mean-3*std)].index, inplace=True)
#         print(df.sort_values('per_capita_income', ascending=True))
        return df

    else:
        print("incorrect sign selected")

# %%
# Answer to question 2: check for rows with missing/null/invalid values

# function to check for null values in dataframe
def check_for_null(df):
    for i in df.columns:
        print(f"{i} has {len(df[df[i].isnull()==True])} 'null' values and {len(df[df[i]==0])} '0' values remaining")
        
# function to check for asterisk (*) in dataframe
def check_for_asterisk(df):
    for i in df.columns:
        print(f"{i} has {len(df[df[i] == '*'])} '*' remaining")

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Answers to question 1

df_act.head()
df_sat.head()
df_income.head()
df_demograph.head()
# Out:
#         county     Men   Women  Hispanic  White  Black  Native  Asian  \
# 186    Alameda  799649  829966      22.5   32.2   10.7     0.3   28.7
# 187     Alpine     664     539       9.7   64.6    1.5    20.6    0.7
# 188     Amador   20005   17301      13.2   79.3    2.0     0.7    1.5
# 189      Butte  111587  113620      15.7   72.9    1.5     0.7    4.4
# 190  Calaveras   22292   22765      11.5   82.0    0.6     0.9    1.2
#
#      Pacific  Income  IncomePerCap  Poverty  Unemployment  minority
# 186      0.8   85743         41363     11.3           6.0      67.8
# 187      0.0   63438         27448     19.8          14.6      35.4
# 188      0.2   60636         29628     10.6           9.3      20.7
# 189      0.2   46516         26304     20.5           9.1      27.1
# 190      0.5   54800         31652     12.8           7.1      18.0

# %% [markdown]
# ---

# %% [markdown]
# # Data cleaning for ACT dataset

# %%
# ACT benchmark: average score is around 20.8 and it is not graded on a curve (not normally distributed) 
# score ranges from 1 to 36, based on scaled score of English, Math, REeading Science 
# https://www.number2.com/average-act-score/
# https://www.crimsoneducation.org/sg/blog/test-prep/good-ACT-score/

# Answer to questions 7 and 8
# - column names renamed to lowercase with underscores (i.e. snake case)
# - column names renamed to be more informative and self-explanatory as much as possible

df_act.rename(columns = {
    'CDS': "county_district_school_code",
    'CCode': "county_code",
    'CDCode': 'county_district_code',
    'SCode': 'school_code',
    'RType': 'record_type',
    'SName': 'school',
    'DName': 'district',
    'CName': 'county',
    'Enroll12': 'num_enrolled_12',
    'NumTstTakr': 'num_test_takers_12',
    'AvgScrRead': 'avg_reading_score',
    'AvgScrEng': 'avg_english_score',
    'AvgScrMath': 'avg_math_score',
    'AvgScrSci': 'avg_science_score',
    'NumGE21': 'num_abv_avg_score',
    'PctGE21': 'pct_abv_avg_score',
    'Year': "year"
    
}, inplace=True)


# Answer to question 3: obvious issues with data sets are as follows:
# - some columns share the same info as other columns (e.g. county_code and county are essentially the same categorical data) and hence one of them will be dropped.
# - the dataset includes "State of California", which needs to be dropped, as it will affect the aggregated values that will be calculated later on.

df_act.drop(columns=['county_district_school_code', 'county_code', 'county_district_code', 'school_code',
                    'record_type', 'year', 'Unnamed: 17', 'avg_reading_score', 'avg_english_score', 
                    'avg_math_score', 'avg_science_score'], inplace=True)

df_act.drop(df_act[df_act.county == "State of California"].index, inplace=True)

# %%
# Answer to question 2: check for rows with missing/null/invalid values

check_for_null(df_act)
print("\n")
check_for_asterisk(df_act)
# Out:
# school has 581 'null' values and 0 '0' values remaining
# district has 59 'null' values and 0 '0' values remaining
# county has 1 'null' values and 0 '0' values remaining
# num_enrolled_12 has 1 'null' values and 2 '0' values remaining
# num_test_takers_12 has 1 'null' values and 356 '0' values remaining
# num_abv_avg_score has 357 'null' values and 0 '0' values remaining
# pct_abv_avg_score has 357 'null' values and 0 '0' values remaining
#
#
# school has 0 '*' remaining
# district has 0 '*' remaining
# county has 0 '*' remaining
# num_enrolled_12 has 0 '*' remaining
# num_test_takers_12 has 0 '*' remaining
# num_abv_avg_score has 532 '*' remaining
# pct_abv_avg_score has 532 '*' remaining

# %%
# Answer to question 4: missing/null/invalid values are found throughout the datasets; the corresponding rows will be dropped
# Answer to question 8: unnecessary rows are dropped

# null and 0 value rows are dropped
df_act.drop((df_act[(df_act['num_test_takers_12'].isnull()) | (df_act['num_test_takers_12'] == 0)]).index, inplace=True)

# drop rows with unwanted asterisk * characters
df_act.drop(df_act[df_act['num_abv_avg_score'] == '*'].index, inplace=True)

# %%
# to verify that all unncessary rows have been dropped correctly
# null values in school and district will not be dropped as it doesnt affect analysis 

check_for_null(df_act)
print("\n")
check_for_asterisk(df_act)
# Out:
# school has 404 'null' values and 0 '0' values remaining
# district has 54 'null' values and 0 '0' values remaining
# county has 0 'null' values and 0 '0' values remaining
# num_enrolled_12 has 0 'null' values and 1 '0' values remaining
# num_test_takers_12 has 0 'null' values and 0 '0' values remaining
# num_abv_avg_score has 0 'null' values and 0 '0' values remaining
# pct_abv_avg_score has 0 'null' values and 0 '0' values remaining
#
#
# school has 0 '*' remaining
# district has 0 '*' remaining
# county has 0 '*' remaining
# num_enrolled_12 has 0 '*' remaining
# num_test_takers_12 has 0 '*' remaining
# num_abv_avg_score has 0 '*' remaining
# pct_abv_avg_score has 0 '*' remaining

# %%
# Answer to question 5: checking dtypes of column values in df_act
df_act.dtypes
# Out:
# school                 object
# district               object
# county                 object
# num_enrolled_12       float64
# num_test_takers_12    float64
# num_abv_avg_score      object
# pct_abv_avg_score      object
# dtype: object

# %%
# Answer to question 6: presence of'*' and null values are preventing score columns to be converted to float, this has been corrected in the earlier data cleaning step of removing rows with '*' and null / 0 values.
# changing dtypes of columns to float
df_act.num_abv_avg_score = df_act.num_abv_avg_score.astype(float)
df_act.pct_abv_avg_score = df_act.pct_abv_avg_score.astype(float)

# %%
# generating new dataframe to better reflect groupby county
df_act_by_county = df_act.groupby('county').mean().reset_index()

# %% [markdown]
# ---

# %% [markdown]
# # Data cleaning for SAT dataset

# %%
df_sat.head(3)

# SAT bnchmk: students with ERW and Math scores >= bnchmk has 75% chance of earning at least C in 1st sem. 
# grade 12 ==> ERW: 480, Math: 530
# grade 11 ==> ERW: 460, Math: 510
#https://collegereadiness.collegeboard.org/about/scores/benchmarks

df_sat.rename(columns = {
    'CDS': "county_district_school_code",
    'CCode': "county_code",
    'CDCode': 'county_district_code',
    'SCode': 'school_code',
    'RType': 'record_type',
    'SName': 'school',
    'DName': 'district',
    'CName': 'county',
    'Enroll12': 'num_enrolled_12',
    'NumTSTTakr12': 'num_test_takers_12',
    'NumERWBenchmark12': "num_erw_bnchmk_12",
    'PctERWBenchmark12': "pct_erw_bnchmk_12",
    'NumMathBenchmark12': "num_math_bnchmk_12",
    'PctMathBenchmark12': "pct_math_bnchmk_12",
    'Enroll11': "num_enrolled_11",
    'NumTSTTakr11': "num_test_takers_11",
    'NumERWBenchmark11': "num_erw_bnchmk_11",
    'PctERWBenchmark11': "pct_erw_bnchmk_11",
    'NumMathBenchmark11': "num_math_bnchmk_11",
    'PctMathBenchmark11': "pct_math_bnchmk_11",
    'TotNumBothBenchmark12': "num_both_bnchmk_12",
    'PctBothBenchmark12': "pct_both_bnchmk_12",
    'TotNumBothBenchmark11': "num_both_bnchmk_11",
    'PctBothBenchmark11': "pct_both_bnchmk_11",
    'Year': "year"

    
}, inplace=True)

# Answer to question 3: obvious issues with data sets are as follows:
# - some columns share the same info as other columns (e.g. county_code and county are essentially the same categorical data) and hence one of them will be dropped.
# - the dataset includes "State of California", which needs to be dropped, as it will affect the aggregated values that will be calculated later on.

df_sat.drop(columns=['county_district_school_code', 'county_code', 'county_district_code', 'school_code',
                    'record_type', 'year', 'Unnamed: 25'], inplace=True)

# %%
# Answer to question 2: check for rows with missing/null/invalid values

check_for_null(df_sat)
print('\n')
check_for_asterisk(df_sat)
# Out:
# school has 598 'null' values and 0 '0' values remaining
# district has 59 'null' values and 0 '0' values remaining
# county has 1 'null' values and 0 '0' values remaining
# num_enrolled_12 has 1 'null' values and 25 '0' values remaining
# num_test_takers_12 has 1 'null' values and 275 '0' values remaining
# num_erw_bnchmk_12 has 276 'null' values and 0 '0' values remaining
# pct_erw_bnchmk_12 has 276 'null' values and 0 '0' values remaining
# num_math_bnchmk_12 has 276 'null' values and 0 '0' values remaining
# pct_math_bnchmk_12 has 276 'null' values and 0 '0' values remaining
# num_enrolled_11 has 1 'null' values and 15 '0' values remaining
# num_test_takers_11 has 1 'null' values and 310 '0' values remaining
# num_erw_bnchmk_11 has 311 'null' values and 0 '0' values remaining
# pct_erw_bnchmk_11 has 311 'null' values and 0 '0' values remaining
# num_math_bnchmk_11 has 311 'null' values and 0 '0' values remaining
# ...

# %%
# naturally, schools with no test takers will have no corresponding SAT scores.
# hence we drop these rows.
df_sat.drop((df_sat[(df_sat['num_test_takers_12'].isnull()) | (df_sat['num_test_takers_12'] == 0)]).index, inplace=True)
df_sat.drop((df_sat[(df_sat['num_test_takers_11'].isnull()) | (df_sat['num_test_takers_11'] == 0)]).index, inplace=True)

# drop rows with unwanted asterisk * characters
df_sat.drop(df_sat[df_sat['num_erw_bnchmk_12'] == '*'].index, inplace=True)
df_sat.drop(df_sat[df_sat['num_erw_bnchmk_11'] == '*'].index, inplace=True)

# %%
# to verify that all unncessary rows have been dropped correctly
# null values in school and district will not be dropped as it doesnt affect analysis 

check_for_null(df_sat)
print('\n')
check_for_asterisk(df_sat)
# Out:
# school has 440 'null' values and 0 '0' values remaining
# district has 54 'null' values and 0 '0' values remaining
# county has 0 'null' values and 0 '0' values remaining
# num_enrolled_12 has 0 'null' values and 0 '0' values remaining
# num_test_takers_12 has 0 'null' values and 0 '0' values remaining
# num_erw_bnchmk_12 has 0 'null' values and 0 '0' values remaining
# pct_erw_bnchmk_12 has 0 'null' values and 0 '0' values remaining
# num_math_bnchmk_12 has 0 'null' values and 0 '0' values remaining
# pct_math_bnchmk_12 has 0 'null' values and 0 '0' values remaining
# num_enrolled_11 has 0 'null' values and 0 '0' values remaining
# num_test_takers_11 has 0 'null' values and 0 '0' values remaining
# num_erw_bnchmk_11 has 0 'null' values and 0 '0' values remaining
# pct_erw_bnchmk_11 has 0 'null' values and 0 '0' values remaining
# num_math_bnchmk_11 has 0 'null' values and 0 '0' values remaining
# pct_math_bnchmk_11 has 0 'null' values and 0 '0' values remaining
# ...

# %%
# Answer to question 5: checking dtypes of column values in df_sat
df_sat.dtypes
# Out:
# school                 object
# district               object
# county                 object
# num_enrolled_12       float64
# num_test_takers_12    float64
# num_erw_bnchmk_12      object
# pct_erw_bnchmk_12      object
# num_math_bnchmk_12     object
# pct_math_bnchmk_12     object
# num_enrolled_11       float64
# num_test_takers_11    float64
# num_erw_bnchmk_11      object
# pct_erw_bnchmk_11      object
# num_math_bnchmk_11     object
# pct_math_bnchmk_11     object
# num_both_bnchmk_12     object
# pct_both_bnchmk_12     object
# num_both_bnchmk_11     object
# pct_both_bnchmk_11     object
# dtype: object

# %%
# change dtypes to respective appropriate dtypes
df_sat.iloc[:,3:] = df_sat.iloc[:,3:].astype(float)
df_sat.iloc[:,[3,4,5,7,9,10,11,13,15,17]] = df_sat.iloc[:,[3,4,5,7,9,10,11,13,15,17]].astype(int)

# %%
df_sat_by_county = df_sat.groupby('county').mean().reset_index()

# %%
# found State of California data that results skewed data:
df_sat_by_county.sort_values('num_test_takers_11', ascending = False)

# drop State of California
df_sat_by_county.drop(df_sat_by_county[df_sat_by_county['county'] == 'State of California'].index, inplace=True)

# rename column names for better viewing
col_names = ['county', 'num_enrolled_12', 'num_test_takers_12', 'num_erw_bnchmk_12', 'pct_erw_bnchmk_12',
             'num_math_bnchmk_12', 'pct_math_bnchmk_12', 'num_both_bnchmk_12', 'pct_both_bnchmk_12',
             'num_enrolled_11', 'num_test_takers_11', 'num_erw_bnchmk_11','pct_erw_bnchmk_11',
             'num_math_bnchmk_11', 'pct_math_bnchmk_11', 'num_both_bnchmk_11', 'pct_both_bnchmk_11']
df_sat_by_county = df_sat_by_county.reindex(columns=col_names)

# %% [markdown]
# ---

# %% [markdown]
# # Creating new columns for participation rates for both ACT and SAT datasets

# %%
# creating new columns to calculate participation rate in all 3 tests
df_sat_by_county["participation_rate_sat12"] = df_sat_by_county.num_test_takers_12 / df_sat_by_county.num_enrolled_12
df_sat_by_county["participation_rate_sat11"] = df_sat_by_county.num_test_takers_11 / df_sat_by_county.num_enrolled_11
df_act_by_county["participation_rate_act12"] = df_act_by_county.num_test_takers_12 / df_act_by_county.num_enrolled_12

# %% [markdown]
# ---

# %% [markdown]
# # Merge demographic, income, ACT, and SAT datasets for analysis

# %%
# Answer to question 9 and 10: Merge and clean data
# applying function created earlier to remove outliers from df_income
# outliers in this case are deemed to be counties having per_capita_income > (mean + 3*std)
remove_outliers(df_income, 'per_capita_income', "plus")

# selecting only the columns required to analyse 
df_minority = pd.DataFrame(df_demograph.loc[:,['county','minority']])
df_sat_by_county2 = df_sat_by_county.iloc[:,[0,8,16,17,18]]
df_act_by_county2 = df_act_by_county.iloc[:,[0,4,5]]

a = pd.merge(df_act_by_county2, df_sat_by_county2, on='county')
b = pd.merge(a, df_income, on='county', how="left")
df_analysis = pd.merge(b,df_minority, on="county", how="left")
# Out:
# outliers are:            county  per_capita_income
# 20          Marin           141735.0
# 37  San Francisco           139405.0
# 40      San Mateo           134107.0

# %%
# Answer to question 11, exporting csv file
df_analysis.to_csv('dataframe_analysis.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |county|object|df_analysis|The name of county|
# |pct_abv_avg_score|float64|df_analysis|The percentage of grade 12 students scoring above average in ACT (>=21 points) in each county|
# |participation_rate_act12|float64|df_analysis|The participation rate of ACT test amongst grade 12 enrolled students in each county|
# |pct_both_bnchmk_12|float64|df_analysis|The percentage of grade 12 students scoring above the benchmark for both ERW and Math in SAT (ERW: 480, Math: 530) in each county|
# |pct_both_bnchmk_11|float64|df_analysis|The percentage of grade 11 students scoring above the benchmark for both ERW and Math in SAT (ERW: 460, Math: 510) in each county|
# |participation_rate_sat12|float64|df_analysis|The participation rate of SAT test amongst grade 12 enrolled students in each county|
# |participation_rate_sat11|float64|df_analysis|The participation rate of SAT test amongst grade 11 enrolled students in each county|
# |per_capita_income|float64|df_analysis|Income per capita of each county|
# |minority|float64|df_analysis|The percentage of minority (defined as non-whites) in each county|

# %% [markdown]
# ---

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Data exploration by county

# %%
# Answer to question 1: show statistics of dataframes
df_sat_by_county.describe()
df_act_by_county.describe()
# Out:
#        num_enrolled_12  num_test_takers_12  num_abv_avg_score  \
# count        54.000000           54.000000          54.000000
# mean        647.051929          107.700844          61.918111
# std         333.694562           71.594119          50.089137
# min          49.800000           15.000000           6.333333
# 25%         392.575000           40.728571          20.687500
# 50%         656.703008          106.350311          46.776786
# 75%         851.262500          151.758929          86.988777
# max        1374.220930          295.848837         211.918605
#
#        pct_abv_avg_score  participation_rate_act12
# count          54.000000                 54.000000
# mean           56.029991                  0.170248
# std            16.309580                  0.098619
# min            16.668000                  0.044402
# 25%            42.731170                  0.106632
# 50%            59.082760                  0.151056
# ...

# %% [markdown]
# The above 2 codes show a quick look at the statistical information fo both SAT and ACT datasets grouped by county.

# %%
# Answer to question 2: dict comprehension for sd function
# Using SAT grouped by county dataframe (df_sat_by_county)

my_dict = dict(enumerate(df_sat_by_county.set_index('county')))
my_dict = {v:k for (k,v) in my_dict.items()}
sd = {k:std_dev(df_sat_by_county.set_index('county')[k]) for k in my_dict}
sd
# Out:
# {'num_enrolled_12': 293.9126530535598,
#  'num_test_takers_12': 128.09131189794323,
#  'num_erw_bnchmk_12': 88.85827850645259,
#  'pct_erw_bnchmk_12': 9.823571163048205,
#  'num_math_bnchmk_12': 69.3560306945227,
#  'pct_math_bnchmk_12': 13.565649646425683,
#  'num_both_bnchmk_12': 66.0017904178553,
#  'pct_both_bnchmk_12': 13.737448878739578,
#  'num_enrolled_11': 289.6702148380912,
#  'num_test_takers_11': 155.97507547332853,
#  'num_erw_bnchmk_11': 114.34711465988248,
#  'pct_erw_bnchmk_11': 8.784324117527895,
#  'num_math_bnchmk_11': 95.48593490544337,
#  'pct_math_bnchmk_11': 13.487186537055699,
#  'num_both_bnchmk_11': 92.44273062798341,
#  'pct_both_bnchmk_11': 13.606796096008885,
#  'participation_rate_sat12': 0.08273799714730959,
#  'participation_rate_sat11': 0.1274088809549597}

# %% [markdown]
# The above shows standard deviation values for all features of SAT tests grouped by county.

# %%
# Answer to question 3: investigate trends

# top 10 best performing schools in terms of percentage of students scoring >= 21 in ACT:
df_act.sort_values(by='pct_abv_avg_score', ascending=False)

# top 10 best performing counties in terms of percentage of students scoring >= 21 in ACT
df_act_by_county.sort_values(by='pct_abv_avg_score', ascending=False).head(5)

# More trends/findings have been investigated further below.
# Out:
#        county  num_enrolled_12  num_test_takers_12  num_abv_avg_score  \
# 3   Calaveras       285.333333           23.000000          19.666667
# 23       Mono       208.333333           19.333333          15.333333
# 1      Amador       211.250000           27.750000          21.750000
# 50   Tuolumne       518.000000           23.000000          18.000000
# 18      Marin       681.818182          203.818182         163.727273
#
#     pct_abv_avg_score  participation_rate_act12
# 3           85.173333                  0.080607
# 23          79.300000                  0.092800
# 1           78.970000                  0.131361
# 50          78.260000                  0.044402
# 18          76.794545                  0.298933

# %% [markdown]
# The best performing counties in grade 12 ACT tests are Calaveras, Mono, Amador, Tuolumne, Marin

# %%
# we would like to see all counties in the 25th percentile for partcipation rate in ACT grade 12
# use mask to generate counties where participation rate is lower than the 25th percentile
mask = df_act_by_county['participation_rate_act12'] < df_act_by_county.describe().at["25%", "participation_rate_act12"]
df_act_by_county[mask].sort_values('participation_rate_act12', ascending=True).head(5)
# Out:
#        county  num_enrolled_12  num_test_takers_12  num_abv_avg_score  \
# 50   Tuolumne       518.000000               23.00          18.000000
# 26     Nevada       762.500000               48.75          36.750000
# 20  Mendocino       420.800000               32.20          21.800000
# 53       Yuba       383.166667               30.50          13.833333
# 3   Calaveras       285.333333               23.00          19.666667
#
#     pct_abv_avg_score  participation_rate_act12
# 50          78.260000                  0.044402
# 26          74.695000                  0.063934
# 20          68.824000                  0.076521
# 53          46.158333                  0.079600
# 3           85.173333                  0.080607

# %% [markdown]
# The lowest participating counties in grade 12 ACT tests are Tuolumne, Nevada, Mendocino, Yuba, Calaveras

# %% [markdown]
# ---

# %% [markdown]
# ### Analysis of worst performing counties in all 3 tests
# - The worst performing countites are found to be ['Colusa', 'Merced', 'Glenn', 'Fresno', 'Kings']
# - Interestingly, these 5 counties all have minority percentage higher than the statewide median value.
# - The table below also shows the differences in minority percentage between these 5 counties and the statewide mean value. As shown, 4 out of 5 have alot higher minority than the statewide mean value.

# %%
# Investigate PERFORMANCE of counties in SAT and ACT
# 5 counties are consistently performing in the bottom 10 in both ACT12, SAT12, SAT11

# bottom 10 least performing in SAT grade 12
a1 = df_sat_by_county.sort_values('pct_both_bnchmk_12', ascending=True).head(10).loc[:,["county", "pct_both_bnchmk_12"]]
# bottom 10 least performing in SAT grade 11
a2 = df_sat_by_county.sort_values('pct_both_bnchmk_11', ascending=True).head(10).loc[:,["county", "pct_both_bnchmk_11"]]
# bottom 10 least performing in ACT grade 12
a3 = df_act_by_county.sort_values('pct_abv_avg_score', ascending=True).head(10).loc[:,["county", "pct_abv_avg_score"]]

a4 = pd.merge(a1,a2,on='county')
a5 = pd.merge(a4,a3,on='county')

print(f"List of counties consistently in bottom 10 for ACT and SAT test scores: {[i for i in a5.county]}")

# table showing differences in minority percentage between these 5 counties and the mean value
a5 = a5.merge(df_minority, on="county")
a5["minority difference"] = a5["minority"] - df_minority.mean()[0]
a5
# Out:
# List of counties consistently in bottom 10 for ACT and SAT test scores: ['Colusa', 'Merced', 'Glenn', 'Fresno', 'Kings']
#    county  pct_both_bnchmk_12  pct_both_bnchmk_11  pct_abv_avg_score  \
# 0  Colusa            9.500000           39.870000          32.373333
# 1  Merced           25.836190           41.370476          30.820526
# 2   Glenn           26.331429           43.414286          34.656000
# 3  Fresno           31.194151           36.234906          34.744146
# 4   Kings           34.207500           43.264167          30.920000
#
#    minority  minority difference
# 0      63.7            18.462069
# 1      71.2            25.962069
# 2      47.5             2.262069
# 3      69.8            24.562069
# 4      66.9            21.662069

# %% [markdown]
# ### Analysis of worst participating counties in all 3 tests
# - The worst participating counties in SAT and ACT tests are found to be ['Tuolumne', 'Shasta', 'Yuba']

# %%
# Investigate PARTICIPATION of counties in SAT and ACT
# 3 counties are participating least in all 3 tests (ACT12, SAT12, SAT11)

# bottom 10 least participating in SAT grade 12
c1 = df_sat_by_county.sort_values("participation_rate_sat12", ascending=True).head(10).loc[:,["county","participation_rate_sat12"]]
# bottom 10 least participating in SAT grade 11
c2 = df_sat_by_county.sort_values("participation_rate_sat11", ascending=True).head(10).loc[:,["county","participation_rate_sat11"]]
# bottom 10 least participating in ACT grade 12
c3 = df_act_by_county.sort_values("participation_rate_act12", ascending=True).head(10).loc[:,["county","participation_rate_act12"]]

c4 = pd.merge(c1,c2,on='county')
c5 = pd.merge(c4,c3,on='county')

print(f"List of counties consistently in bottom 10 for participation of ACT and SAT tests: {[i for i in c5.county]}")
# Out:
# List of counties consistently in bottom 10 for participation of ACT and SAT tests: ['Tuolumne', 'Shasta', 'Yuba']

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Heatmap  for correlation
# - Heatmap is produced to show the correlation values of various features in df_analysis.
# - This is to be accompanied with pairplot in the next visualisation.

# %%
df_analysis.corr()
sns.heatmap(df_analysis.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Pairplots for correlation
# - Pairplots plotted to give a general overview of potential relationships between any 2 features of df_analysis
# - Higher minority percentage in a county is strongly correlated to lower performances in ACT and SAT tests.
# - Higher minority percentage in a county is moderately correlated to higher participation rates in SAT tests but negligble in ACT tests.
# - Higher income per capita in a county is moderately associated with higher performances in ACT and SAT tests.
# - Higher income per capita in a county is moderately associated with higher participation rates in ACT and SAT tests. However, it is worth noting that correlation is more positive for SAT than for ACT.
# - Understandably so, counties with higher performances in ACT tests is strongly associated with higher performances in SAT tests.

# %%
sns.pairplot(df_analysis, kind='reg')

# %% [markdown]
# ### lmplot to show regression against the scatterplot
# - The lmplot adds hue to further understand a 3rd dimension which is income per capita.
# - Generally, a higher minority percentage county performs worse in ACT and SAT test scores.
# - Generally, higher income per capita leads to better ACT and SAT test scores, but this is not a strong correlation.

# %%
g1 = sns.lmplot(x="minority", y="pct_abv_avg_score", hue="per_capita_income", palette = 'flare', 
               data=df_analysis, fit_reg=False, legend=False)
sns.regplot(x="minority", y="pct_abv_avg_score", data=df_analysis, scatter=False, ax=g1.axes[0, 0],
            line_kws={"color":"darkred","alpha":0.3,"lw":4})
g1 = (g1.set_axis_labels("% minority", "% above average scores"))
plt.title("ACT taken by Grade 12 \n (scatter hue: income per capita)")
plt.xlim((0,100))
plt.ylim((0,100))
# Out:
# (0.0, 100.0)

# %%
g2 = sns.lmplot(x="minority", y="pct_both_bnchmk_12", hue="per_capita_income", palette = 'flare', 
               data=df_analysis, fit_reg=False, legend=False)
sns.regplot(x="minority", y="pct_both_bnchmk_12", data=df_analysis, scatter=False, ax=g2.axes[0, 0],
            line_kws={"color":"darkred","alpha":0.3,"lw":4})
g2 = (g2.set_axis_labels("% minority", "% above average scores"))
plt.title("SAT taken by Grade 12 \n (scatter hue: income per capita)")
plt.xlim((0,100))
plt.ylim((0,100))
# Out:
# (0.0, 100.0)

# %%
g3 = sns.lmplot(x="minority", y="pct_both_bnchmk_11", hue="per_capita_income", palette = 'flare', 
               data=df_analysis, fit_reg=False, legend=False)
sns.regplot(x="minority", y="pct_both_bnchmk_11", data=df_analysis, scatter=False, ax=g3.axes[0, 0],
            line_kws={"color":"darkred","alpha":0.3,"lw":4})
g3 = (g3.set_axis_labels("% minority", "% above average scores"))
plt.title("SAT taken by Grade 11 \n (scatter hue: income per capita)")
plt.xlim((0,100))
plt.ylim((0,100))
# Out:
# (0.0, 100.0)

# %%
g4 = sns.lmplot(x="per_capita_income", y="pct_abv_avg_score", hue="minority", palette = 'flare', 
               data=df_analysis, fit_reg=False, legend=False)

sns.regplot(x="per_capita_income", y="pct_abv_avg_score", data=df_analysis, scatter=False, ax=g4.axes[0, 0],
            line_kws={"color":"darkred","alpha":0.3,"lw":4})

g4 = (g4.set_axis_labels("income per capita", "% above average scores"))
plt.title("ACT taken by Grade 12 \n (scatter hue: minority %)")
plt.ylim((0,100))
# Out:
# (0.0, 100.0)

# %%
g4 = sns.lmplot(x="per_capita_income", y="pct_both_bnchmk_12", hue="minority", palette = 'flare', 
               data=df_analysis, fit_reg=False, legend=False)

sns.regplot(x="per_capita_income", y="pct_both_bnchmk_12", data=df_analysis, scatter=False, ax=g4.axes[0, 0],
            line_kws={"color":"darkred","alpha":0.3,"lw":4})

g4 = (g4.set_axis_labels("income per capita", "% above average scores"))
plt.title("SAT taken by Grade 12 \n (scatter hue: minority %)")
plt.ylim((0,100))
# Out:
# (0.0, 100.0)

# %%
g4 = sns.lmplot(x="per_capita_income", y="pct_both_bnchmk_11", hue="minority", palette = 'flare', 
               data=df_analysis, fit_reg=False, legend=False)

sns.regplot(x="per_capita_income", y="pct_both_bnchmk_11", data=df_analysis, scatter=False, ax=g4.axes[0, 0],
            line_kws={"color":"darkred","alpha":0.3,"lw":4})

g4 = (g4.set_axis_labels("income per capita", "% above average scores"))
plt.title("SAT taken by Grade 11 \n (scatter hue: minority %)")
plt.ylim((0,100))
# Out:
# (0.0, 100.0)

# %% [markdown]
# ### Areas for Improvement
#
# - Income inequality between counties/districts
# - Racial proportions within each school
# - Fundings within each county

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are your key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Conclusions:**
#
# From this project, we have concluded that there is a negative correlation between minority percentages and test performances. A higher minority percentage county likely means that there are racial segregation. This is also supported by research which shows high levels of racial segregation in schools leads to poorer education levels and even beyond in terms of job opportunities (https://ssri.psu.edu/news/new-research-details-increasing-segregation-transformed-school-population).
#
# Furthermore, we have identified the worst performing counties that also happen to have high percentages of minority. If resources need to be allocated promptly, these are the 5 counties that require funding in terms of improving education level and racial segregation of students in schools.
#
# **Recommendations:**
#
# The State of California could impose a racial quota in schools, as far as possible. The racial quota should reflect the statewide percentages, so that schools have well balanced student demographics. This can potentially translate to better test performances and even better job opportunities as supported by research.
#
# As a start, the state could look into funding the 5 counties (Colusa, Merced, Glenn, Fresno, Kings) identified as the worst performing ones which also have high levels of minority percentage. Following which, the state could look into assisting schools in Los Angeles which has the most number of schools. The main objective is to prevent racial segregation by introducing racial quota for each school. In regions where introducing a racial quota is not feasible, efforts should be introduced to promote racial integerations within schools.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
