# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean_value(num_list:list):
    res = 0
    for num in num_list:
        res += num
    return res/(len(num_list))

mean_value([1,2,4,5,7,2,3,43])
# Out:
# 8.375

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(num_list:list):
    val = 0
    for num in num_list:   
        val += (num - mean_value(num_list))**2
    return (val/len(num_list))**0.5

std_dev([1,2,4,5,7,2,3,43])
# Out:
# 13.209253385411305

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def data_cleaning(string:str):
    string_num = string.replace("%","")
    return float(string_num) / 100

data_cleaning("30.5%")
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:

df_act = pd.read_csv('../data/act_2019_ca.csv')
df_sat = pd.read_csv('../data/sat_2019_ca.csv')
df_income = pd.read_csv('../data/CA_income_data_2019.csv')

# %% [markdown]
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
# Answers to question 1
df_act.head()
df_sat.head()
df_income.head()
# Out:
#    Year  Period              Area Per Capita Personal Income - BEA
# 0  2019  Annual    Alameda County                         $81,171
# 1  2019  Annual     Alpine County                         $72,155
# 2  2019  Annual     Amador County                         $45,920
# 3  2019  Annual      Butte County                         $47,860
# 4  2019  Annual  Calaveras County                         $51,131

# %% [markdown]
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# the ACT score ranges from 1 to 36. Check for the min and max scores:

# %%
# Answer to question 2: check for rows with missing/null/invalid values
len(df_act[df_act.num_score_grtr_21.isnull() == True]) # 357 null rows
len(df_act[df_act.num_score_grtr_21 == "*"]) # 532 invalid rows


# Answer to question 4: missing/null/invalid values are found throughout the datasets; the corresponding rows will be dropped
# Answer to question 8: unnecessary rows are dropped
# 889 null/invalid rows dropped as these may affect analysis later on
df_act_dropped = df_act.drop(df_act[(df_act.num_score_grtr_21 == "*") | (df_act.num_score_grtr_21.isnull() == True)].index)

# %%
# function to confirm remaining null values in dataframe
def check_for_null(df):
    for i in df.columns:
        print(f"{i} has {len(df[df[i].isnull()==True])} null values remaining")
    
check_for_null(df_act_dropped)
# there are 404 rows with null values in school_name
# there are 54 rows with null values in district_name
# however, these will not be dropped as the values do not affect much since analysis will be done on county_name instead
# Out:
# school_name has 404 null values remaining
# district_name has 54 null values remaining
# county_name has 0 null values remaining
# num_of_grade12_enrollment has 0 null values remaining
# num_of_test_takers has 0 null values remaining
# num_score_grtr_21 has 0 null values remaining
# pct_score_grtr_21 has 0 null values remaining

# %%
# Answer to question 5: checking dtypes of column values in df_act_dropped
df_act_dropped.dtypes
# Out:
# school_name                   object
# district_name                 object
# county_name                   object
# num_of_grade12_enrollment    float64
# num_of_test_takers           float64
# num_score_grtr_21             object
# pct_score_grtr_21             object
# dtype: object

# %%
# Answer to question 6: presence of'*' and null values are preventing score columns to be converted to float, this has been corrected in the earlier data cleaning step of removing rows with '*' and null values.
# changing types of all columns related to score to float (i.e. numeric)
df_act_dropped.num_score_grtr_21 = df_act_dropped.num_score_grtr_21.astype(float)
df_act_dropped.pct_score_grtr_21 = df_act_dropped.pct_score_grtr_21.astype(float)

# %%
# generating new dataframe to better reflect groupby county_name
df_groupby_county = df_act_dropped.groupby('county_name').mean().reset_index()

# %%
# data cleaning df_income (external datasets)
# Answers to questions 2 to 8 below:

# rename columns
df_income.columns = ['year', 'period', 'county_name', 'per_capita_income']
# standardize county_name convention to match that of df_act_dropped 
df_income.county_name = df_income.county_name.str.replace(" County","")
# drop unnecessary columns
df_income.drop(columns=['year', 'period'], inplace=True)
# check for addtional scharacters that are preventing conversion to float type and remove them
df_income["per_capita_income"] = df_income["per_capita_income"].map(lambda x: x.replace("$",""))
df_income["per_capita_income"] = df_income["per_capita_income"].map(lambda x: x.replace(",",""))
# change per_capita_income column to float type
df_income["per_capita_income"] = df_income["per_capita_income"].astype(float)

# %%
# Answer to question 9: merge 2 datasets 
df_groupby_county_income = pd.merge(df_groupby_county, df_income, how='left', on="county_name")

# %%
# scatter plot generated to see correlation between income and score
# visually, it seems like there are 4 outliers (Marin, San Francisco, San Mateo, Santa Clara) 
plt.scatter(df_groupby_county_income.per_capita_income, df_groupby_county_income.pct_score_grtr_21)

df_groupby_county_income.describe()
# check again if they are outliers based on (mean +- 3*std) threshold
# found that 3 out of the 4 are outliers based on statistical calculation
df_groupby_county_income[df_groupby_county_income.per_capita_income > 
                         (df_groupby_county_income.per_capita_income.describe()['mean'] + 3*df_groupby_county_income.per_capita_income.describe()['std'])]
# Out:
#       county_name  num_of_grade12_enrollment  num_of_test_takers  \
# 18          Marin                 681.818182          203.818182
# 34  San Francisco                 712.388889          178.555556
# 37      San Mateo                 735.571429          152.678571
#
#     num_score_grtr_21  pct_score_grtr_21  per_capita_income
# 18         163.727273          76.794545           141735.0
# 34          93.888889          42.502778           139405.0
# 37         111.714286          68.088929           134107.0

# %%
# Answer to question 10: additional cleaning
# drop the 3 outliers that were calculated earlier based on (mean +- 3*std) threshold
df_groupby_county_income.drop(df_groupby_county_income[df_groupby_county_income.per_capita_income > (df_groupby_county_income.per_capita_income.describe()['mean'] + 3*df_groupby_county_income.per_capita_income.describe()['std'])].index, inplace=True)

plt.scatter(df_groupby_county_income.per_capita_income, df_groupby_county_income.pct_score_grtr_21)
plt.xlabel("per capita income")
plt.ylabel("percentage of students with score >= 21")
plt.xlim()
# Out:
# (35770.3, 87683.7)

# %%
plt.scatter(df_groupby_county['num_of_test_takers'],df_groupby_county['num_score_grtr_21'])
plt.xlabel("no. of students took test")
plt.ylabel("no. of students scoring >= 21")
# Out:
# Text(0, 0.5, 'no. of students scoring >= 21')

# %%
sns.lmplot(x='per_capita_income', y='pct_score_grtr_21', data=df_groupby_county_income)

# %%
sns.pairplot(df_groupby_county_income)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# # --- External datasets cleanup ---

# %% [markdown]
# # --- SAT ACT California ---

# %%
sns.pairplot(act19_ca[['TestTakers', 'PercentAccepted', 'TotalScore', 'ReadingWriting', 'Math']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-714-0b1c75cd3d4d> in <module>
# ----> 1 sns.pairplot(act19_ca[['TestTakers', 'PercentAccepted', 'TotalScore', 'ReadingWriting', 'Math']])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['TestTakers', 'PercentAccepted', 'TotalScore', 'ReadingWriting',\n       'Math'],\n      dtype='object')] are in the [columns]"

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |county_name|object|ACT|This is an example|
# |num_of_grade12_enrollment|float64|ACT|number of grade 12 students enrolled in each county|
# |num_of_test_takers|float64|ACT|number of students taking the test in each county|
# |num_score_grtr_21|float64|ACT|The number of students who had ACT scores greater than 21 in each county|
# |pct_score_grtr_21|float64|ACT|The percentage of students who had ACT scores greater than 21 in each county|
# |per_capita_income|float64|income|the average per capita income of each county|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code: 
# Answer to 1. Summary Statistics
df_groupby_county_income.describe()

# %%
# Code:
def std_dev(num_list:list):
    val = 0
    for num in num_list:   
        val += (num - mean_value(num_list))**2
    return (val/len(num_list))**0.5

std_dev([1,2,4,5,7,2,3,43])

# %%
sd = {v:std_dev(df_groupby_county_income[v]) for (k,v) in enumerate(df_groupby_county_income.set_index('county_name').columns) }
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'county_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-772-735a4483b67a> in <module>
# ----> 1 sd = {v:std_dev(df_groupby_county_income.set_index('county_name')[v]) for (k,v) in enumerate(df_groupby_county_income.columns) }
#
# <ipython-input-772-735a4483b67a> in <dictcomp>(.0)
# ----> 1 sd = {v:std_dev(df_groupby_county_income.set_index('county_name')[v]) for (k,v) in enumerate(df_groupby_county_income.columns) }
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'county_name'

# %%
# Answer to question 2: dict comprehension for sd function

my_dict = dict(enumerate(df_groupby_county_income.set_index('county_name')))
my_dict = {v:k for (k,v) in my_dict.items()}
sd = {k:std_dev(df_groupby_county_income.set_index('county_name')[k]) for k in my_dict}

sd
# Out:
# {'num_of_grade12_enrollment': 337.8701719447769,
#  'num_of_test_takers': 69.32686888925055,
#  'num_score_grtr_21': 45.82250771214305,
#  'pct_score_grtr_21': 16.181885832477974,
#  'per_capita_income': 11496.383208105059}

# %%
df3 = df_groupby_county_income.dset_index('county_name').items()
print(df3)
# Out:
# <generator object DataFrame.items at 0x7ff41e43e350>

# %%
std_dev(df_groupby_county_income['num_of_grade12_enrollment'])
# Out:
# 337.8701719447769

# %%
df_groupby_county_income.describe()
# Out:
#        num_of_grade12_enrollment  num_of_test_takers  num_score_grtr_21  \
# count                  50.000000           50.000000          50.000000
# mean                  634.955601          101.186041          56.021092
# std                   341.300414           70.030713          46.287723
# min                    49.800000           15.000000           6.333333
# 25%                   309.791667           34.892857          19.858333
# 50%                   628.376087           99.503759          44.875000
# 75%                   851.262500          136.508523          79.025815
# max                  1374.220930          295.848837         211.918605
#
#        pct_score_grtr_21  per_capita_income
# count          50.000000          50.000000
# mean           55.345753       54000.820000
# std            16.346173       11613.100751
# min            16.668000       38130.000000
# 25%            42.731170       44566.000000
# 50%            57.428125       51109.500000
# 75%            69.356000       62907.500000
# max            85.173333       85324.000000

# %%
# Answer to question 3: investigate trends
df_groupby_county_income.head(3)

# we would like to see all the counties' per_capita_income
df_groupby_county_income['per_capita_income'].head(3)

# we would like to see all counties in the 25th percentile 
# use mask to generate counties where per_capita_income is lower than the 25th percentile
mask = df_groupby_county_income['per_capita_income'] < df_groupby_county_income.describe().at["25%", "per_capita_income"]
df_groupby_county_income[mask].head(3)

# we would like to see top 10 California counties with highest percentage of students scoring >= 21 in ACT:
# these are the top 10 best performing counties in terms of percentage of students scoring >= 21 in ACT
df_groupby_county_income.sort_values(by='pct_score_grtr_21', ascending=False).head(10)

# top 10 best performing schools in California:
df_act.sort_values(by='pct_score_grtr_21', ascending=False)
# Out:
#                                                                             school_name  \
# 2271                                                            Whitney (Gretchen) High
# 1809                                                                      Piedmont High
# 1025                                                                   Monta Vista High
# 1992                                                                      Saratoga High
# 1006                                                              Mission San Jose High
# 1526                                                                                NaN
# 926                                                                       Lynbrook High
# 241                                                                Canyon Crest Academy
# 1766                                                         Pacific Collegiate Charter
# 1533                                                                                NaN
# 916                                                                      Los Gatos High
# 396                                                                      Cupertino High
# 451                                                               Dougherty Valley High
# 176                                                                        Branham High
# 2150                                                                          Troy High
# 1134                                                                                NaN
# 833                                                                       La Jolla High
# 13                                                               Academy of the Canyons
# 1524                                                                                NaN
# 1277                                                                                NaN
# 829                                                                      La Canada High
# 57                                                                          Amador High
# 1704                                                                      Oak Park High
# 2166                                                                    University High
# 16                                                                        Acalanes High
# 718                                                                      Homestead High
# 948                                                                 Maria Carrillo High
# 408                                                                   Davis Senior High
# 1631                                                                                NaN
# 558                                                               Evergreen Valley High
# 1232                                                                                NaN
# 191                                                                      Burroughs High
# 2142                                                                      Torrance High
# 1063                                                               Murrieta Valley High
# 477                                                                       Eastlake High
# 1880                                                                       Redwood High
# 1860                                                                        Ramona High
# 2106                                                                  Taft Charter High
# 1267                                                                                NaN
# 21                                                                   Adrian Wilcox High
# ...
# 333                  *                 *
# 1503                 *                 *
# 332                  *                 *
# 331                  *                 *
# 328                  *                 *
# 1509                 *                 *
# 324                  *                 *
# 1515                 *                 *
# 323                  *                 *
# 1517                 *                 *
# 316                  *                 *
# 314                  *                 *
# 313                  *                 *
# 311                  *                 *
# 2307                 *                 *
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 17                 NaN               NaN
# 28                 NaN               NaN
# 51                 NaN               NaN
# 52                 NaN               NaN
# 55                 NaN               NaN
# 56                 NaN               NaN
# 59                 NaN               NaN
# 60                 NaN               NaN
# 67                 NaN               NaN
# 85                 NaN               NaN
# 98                 NaN               NaN
# 108                NaN               NaN
# 121                NaN               NaN
# 126                NaN               NaN
# 127                NaN               NaN
# 131                NaN               NaN
# 135                NaN               NaN
# 140                NaN               NaN
# 144                NaN               NaN
# 145                NaN               NaN
# 161                NaN               NaN
# 165                NaN               NaN
# 172                NaN               NaN
# 173                NaN               NaN
# 194                NaN               NaN
# 195                NaN               NaN
# 202                NaN               NaN
# 206                NaN               NaN
# 208                NaN               NaN
# 212                NaN               NaN
# 217                NaN               NaN
# 223                NaN               NaN
# 224                NaN               NaN
# 229                NaN               NaN
# 231                NaN               NaN
# 246                NaN               NaN
# 259                NaN               NaN
# 269                NaN               NaN
# 273                NaN               NaN
# 317                NaN               NaN
# 320                NaN               NaN
# 340                NaN               NaN
# 341                NaN               NaN
# 343                NaN               NaN
# 346                NaN               NaN
# 348                NaN               NaN
# 349                NaN               NaN
# 351                NaN               NaN
# 352                NaN               NaN
# 353                NaN               NaN
# 362                NaN               NaN
# 377                NaN               NaN
# 380                NaN               NaN
# 383                NaN               NaN
# 386                NaN               NaN
# 387                NaN               NaN
# 390                NaN               NaN
# 391                NaN               NaN
# 392                NaN               NaN
# 393                NaN               NaN
# 397                NaN               NaN
# 402                NaN               NaN
# 410                NaN               NaN
# 423                NaN               NaN
# 425                NaN               NaN
# 426                NaN               NaN
# 430                NaN               NaN
# 438                NaN               NaN
# 440                NaN               NaN
# 441                NaN               NaN
# 448                NaN               NaN
# 462                NaN               NaN
# 463                NaN               NaN
# 467                NaN               NaN
# 479                NaN               NaN
# 510                NaN               NaN
# 515                NaN               NaN
# 516                NaN               NaN
# 518                NaN               NaN
# 520                NaN               NaN
# 523                NaN               NaN
# 524                NaN               NaN
# 525                NaN               NaN
# 526                NaN               NaN
# 529                NaN               NaN
# 531                NaN               NaN
# 533                NaN               NaN
# 536                NaN               NaN
# 537                NaN               NaN
# 538                NaN               NaN
# 541                NaN               NaN
# 547                NaN               NaN
# 548                NaN               NaN
# 560                NaN               NaN
# 573                NaN               NaN
# 584                NaN               NaN
# 595                NaN               NaN
# 604                NaN               NaN
# 605                NaN               NaN
# 606                NaN               NaN
# 607                NaN               NaN
# 616                NaN               NaN
# 618                NaN               NaN
# 619                NaN               NaN
# 629                NaN               NaN
# 639                NaN               NaN
# 641                NaN               NaN
# 654                NaN               NaN
# 657                NaN               NaN
# 660                NaN               NaN
# 673                NaN               NaN
# 681                NaN               NaN
# 682                NaN               NaN
# 685                NaN               NaN
# 696                NaN               NaN
# 697                NaN               NaN
# 699                NaN               NaN
# 708                NaN               NaN
# 719                NaN               NaN
# 720                NaN               NaN
# 727                NaN               NaN
# 733                NaN               NaN
# 735                NaN               NaN
# 738                NaN               NaN
# 740                NaN               NaN
# 742                NaN               NaN
# 747                NaN               NaN
# 748                NaN               NaN
# 753                NaN               NaN
# 755                NaN               NaN
# 756                NaN               NaN
# 757                NaN               NaN
# 758                NaN               NaN
# 760                NaN               NaN
# 766                NaN               NaN
# 767                NaN               NaN
# 771                NaN               NaN
# 772                NaN               NaN
# 795                NaN               NaN
# 812                NaN               NaN
# 816                NaN               NaN
# 821                NaN               NaN
# 823                NaN               NaN
# 831                NaN               NaN
# 840                NaN               NaN
# 841                NaN               NaN
# 846                NaN               NaN
# 850                NaN               NaN
# 851                NaN               NaN
# 865                NaN               NaN
# 866                NaN               NaN
# 868                NaN               NaN
# 879                NaN               NaN
# 883                NaN               NaN
# 904                NaN               NaN
# 913                NaN               NaN
# 923                NaN               NaN
# 928                NaN               NaN
# 934                NaN               NaN
# 939                NaN               NaN
# 949                NaN               NaN
# 961                NaN               NaN
# 963                NaN               NaN
# 975                NaN               NaN
# 979                NaN               NaN
# 985                NaN               NaN
# 1000               NaN               NaN
# 1008               NaN               NaN
# 1015               NaN               NaN
# 1016               NaN               NaN
# 1017               NaN               NaN
# 1018               NaN               NaN
# 1019               NaN               NaN
# 1020               NaN               NaN
# 1021               NaN               NaN
# 1039               NaN               NaN
# 1045               NaN               NaN
# 1047               NaN               NaN
# 1049               NaN               NaN
# 1056               NaN               NaN
# 1103               NaN               NaN
# 1122               NaN               NaN
# 1127               NaN               NaN
# 1139               NaN               NaN
# 1145               NaN               NaN
# 1149               NaN               NaN
# 1153               NaN               NaN
# 1167               NaN               NaN
# 1170               NaN               NaN
# 1184               NaN               NaN
# 1187               NaN               NaN
# 1198               NaN               NaN
# 1199               NaN               NaN
# 1203               NaN               NaN
# 1206               NaN               NaN
# 1207               NaN               NaN
# 1211               NaN               NaN
# 1219               NaN               NaN
# 1225               NaN               NaN
# 1234               NaN               NaN
# 1235               NaN               NaN
# 1239               NaN               NaN
# 1247               NaN               NaN
# 1249               NaN               NaN
# 1250               NaN               NaN
# 1314               NaN               NaN
# 1320               NaN               NaN
# 1326               NaN               NaN
# 1331               NaN               NaN
# 1334               NaN               NaN
# 1336               NaN               NaN
# 1346               NaN               NaN
# 1350               NaN               NaN
# 1359               NaN               NaN
# 1411               NaN               NaN
# 1475               NaN               NaN
# 1476               NaN               NaN
# 1477               NaN               NaN
# 1499               NaN               NaN
# 2186               NaN               NaN
# 2187               NaN               NaN
# 2192               NaN               NaN
# 2193               NaN               NaN
# 2197               NaN               NaN
# 2220               NaN               NaN
# 2226               NaN               NaN
# 2228               NaN               NaN
# 2229               NaN               NaN
# 2231               NaN               NaN
# 2239               NaN               NaN
# 2253               NaN               NaN
# 2254               NaN               NaN
# 2285               NaN               NaN
# 2300               NaN               NaN
# 2301               NaN               NaN
# 2305               NaN               NaN
# 2308               NaN               NaN
# 2309               NaN               NaN

# %%
df1 = df_act_dropped.drop(df_act_dropped[df_act_dropped['num_of_test_takers'] >20000].index)
df1.num_score_grtr_21 = df1.num_score_grtr_21.astype(float)
df1.pct_score_grtr_21 = df1.pct_score_grtr_21.astype(float)

sns.pairplot(df1)

# %%
df_act
# Out:
#                                                                             school_name  \
# 0                                                       21st Century Learning Institute
# 1                                                           ABC Secondary (Alternative)
# 2                                                           Abraham Lincoln Alternative
# 3                                                                  Abraham Lincoln High
# 4                                                           Abraham Lincoln Senior High
# 5                                                               Academia Avance Charter
# 6                                 Academies of Education and Empowerment at Carson High
# 7                                                      Academies of the Antelope Valley
# 8                                                            Academy (The)- SF @McAteer
# 9                                                       Academy for Academic Excellence
# 10                  Academy for Multilingual Arts and Science at Mervyn M. Dymally High
# 11                                                   Academy of Careers and Exploration
# 12                                               Academy of Medical Arts at Carson High
# 13                                                               Academy of the Canyons
# 14                                                              Academy of the Redwoods
# 15                                                Acalanes Center for Independent Study
# 16                                                                        Acalanes High
# 17                                                             Accelerated Charter High
# 18                                                                     ACE Charter High
# 19                                                                        Adelanto High
# 20                                                                Adolfo Camarillo High
# 21                                                                   Adrian Wilcox High
# 22                                                                          Agoura High
# 23                                        Alain Leroy Locke College Preparatory Academy
# 24                                                    Alameda Community Learning Center
# 25                                                                         Alameda High
# 26                                             Alameda Science and Technology Institute
# 27                                                                          Albany High
# 28                                                         Alder Grove Charter School 2
# 29                                                       Alexander Hamilton Senior High
# 30                                                                        Alhambra High
# 31                                                                 Alhambra Senior High
# 32                                                                          Alisal High
# 33                                                                    Aliso Niguel High
# 34                                          Alliance Alice M. Baxter College-Ready High
# 35                                Alliance Cindy and Bill Simon Technology Academy High
# 36                                           Alliance Collins Family College-Ready High
# 37                                                         Alliance Dr. Olga Mohan High
# 38                                   Alliance Gertz-Ressler Richard Merkin 6-12 Complex
# 39                                    Alliance Judy Ivie Burton Technology Academy High
# 40               Alliance Leichtman-Levine Family Foundation Environmental Science High
# 41                                           Alliance Marc & Eva Stern Math and Science
# 42                              Alliance Margaret M. Bloomfield Technology Academy High
# 43                                                        Alliance Morgan McKinzie High
# 44                                                Alliance Ouchi-O'Donovan 6-12 Complex
# 45                                 Alliance Patti And Peter Neuwirth Leadership Academy
# 46                             Alliance Piera Barbaglia Shaheen Health Services Academy
# 47                                         Alliance Renee and Meyer Luskin Academy High
# 48                                        Alliance Susan and Eric Smidt Technology High
# 49                                                          Alliance Ted K. Tajima High
# 50                                           Alliance Tennenbaum Family Technology High
# 1986                54             80.60
# 1987                38             76.00
# 1988                26             55.32
# 1989                 3             12.50
# 1990                10             34.48
# 1991               111             62.01
# 1992               117             96.69
# 1993                91             75.21
# 1994                 *                 *
# 1995               NaN               NaN
# 1996               NaN               NaN
# 1997                16             38.10
# 1998                 *                 *
# 1999               NaN               NaN
# 2000                 *                 *
# 2001                 *                 *
# 2002                 *                 *
# 2003                 *                 *
# 2004                 *                 *
# 2005               NaN               NaN
# 2006               NaN               NaN
# 2007                20             50.00
# 2008                13             28.26
# 2009                52             86.67
# 2010               183             90.15
# 2011                15             44.12
# 2012               106             22.08
# 2013                 *                 *
# 2014               NaN               NaN
# 2015                77             63.11
# 2016                21             60.00
# 2017                34             60.71
# 2018                 7             20.59
# 2019                 *                 *
# 2020                16             36.36
# 2021                 *                 *
# 2022                 *                 *
# 2023               NaN               NaN
# 2024                42             91.30
# 2025                47             57.32
# 2026                31             65.96
# 2027                 *                 *
# 2028               NaN               NaN
# 2029               NaN               NaN
# 2030                 *                 *
# 2031               NaN               NaN
# 2032                26             74.29
# 2033                 *                 *
# 2034                 *                 *
# 2035               NaN               NaN
# 2036                34             31.48
# 2037               NaN               NaN
# 2038                41             82.00
# 2039                 *                 *
# 2040                 *                 *
# 2041                18             25.35
# 2042                50             66.67
# 2043                73             86.90
# 2044               NaN               NaN
# 2045                 *                 *
# 2046                33             50.00
# 2047                 *                 *
# 2048                21             61.76
# 2049                 *                 *
# 2050                14             20.29
# 2051               NaN               NaN
# 2052                31             65.96
# 2053                 *                 *
# 2054                51             75.00
# 2055                50             61.73
# 2056                43             28.29
# 2057                21             36.84
# 2058                 *                 *
# 2059                52             23.21
# 2060                 9             29.03
# 2061               116             83.45
# 2062                10             58.82
# 2063                78             83.87
# 2064                14             70.00
# 2065                 *                 *
# 2066                32             59.26
# 2067                32             27.59
# 2068                21             28.77
# 2069                 5             27.78
# 2071                94             75.20
# 2072               NaN               NaN
# 2073                15             34.09
# 2074                70             70.71
# 2075                 *                 *
# 2076                38             52.78
# 2077               NaN               NaN
# 2078                 *                 *
# 2079                 *                 *
# 2080               NaN               NaN
# 2081                13             61.90
# 2082                 *                 *
# 2083                 *                 *
# 2084                79             15.43
# 2085                 *                 *
# 2086                18             41.86
# 2087                15             39.47
# 2088                34             69.39
# 2089                15             48.39
# 2090               NaN               NaN
# 2091                 *                 *
# 2092                 7             24.14
# 2093                99             83.19
# 2094                26             21.67
# 2095                 *                 *
# 2096                 *                 *
# 2097                 4              8.33
# 2098                17             77.27
# 2099               NaN               NaN
# 2100               NaN               NaN
# 2101                38             39.58
# 2102               NaN               NaN
# 2103                 *                 *
# 2104                15             33.33
# 2105                 6             40.00
# 2106                54             67.50
# 2107               NaN               NaN
# 2108                11             31.43
# 2109                39             86.67
# 2110                 7             25.00
# 2111               135             93.10
# 2112                 *                 *
# 2113                 *                 *
# 2114                 *                 *
# 2115                20             83.33
# 2116                 *                 *
# 2117               NaN               NaN
# 2118                15             75.00
# 2119               133             61.86
# 2120                30             47.62
# 2121                80             88.89
# 2122                50             72.46
# 2123               NaN               NaN
# 2124                 *                 *
# 2125                39             69.64
# 2126                19             82.61
# 2127               209             80.69
# 2128               NaN               NaN
# 2129                 *                 *
# 2130                 *                 *
# 2131                27             27.84
# 2132               NaN               NaN
# 2133                 9             13.24
# 2134                 *                 *
# 2135                31             44.93
# 2136                 1              2.00
# 2137               NaN               NaN
# 2138               103             86.55
# 2139               NaN               NaN
# 2140                45             48.91
# 2141                 *                 *
# 2142                71             67.62
# 2143               326             91.83
# 2144               126             82.89
# 2145                41             68.33
# 2146                 0              0.00
# 2147                11             73.33
# 2148                 *                 *
# 2149               NaN               NaN
# 2150               170             95.51
# 2151                28             42.42
# 2152                29             31.18
# 2153                 1              6.67
# 2154                36             67.92
# 2155               NaN               NaN
# 2156                70             42.68
# 2157                 *                 *
# 2158                 *                 *
# 2159                 4             19.05
# 2160                15             68.18
# 2161                 *                 *
# 2162                22             53.66
# 2163                32             66.67
# 2164               101             87.83
# 2165                79             91.86
# 2166               219             93.99
# 2167                25             43.10
# 2168               NaN               NaN
# 2169                21             87.50
# 2170                24             55.81
# 2171                27             81.82
# 2172                 *                 *
# 2173                 7             20.59
# 2174                30             48.39
# 2175               NaN               NaN
# 2176               NaN               NaN
# 2177               NaN               NaN
# 2178               NaN               NaN
# 2179                 4             22.22
# 2180               NaN               NaN
# 2181                34             58.62
# 2182               NaN               NaN
# 2183               129             79.14
# 2184                95             54.91
# 2185                67             78.82
# 2186               NaN               NaN
# 2187               NaN               NaN
# 2188                 *                 *
# 2189                 *                 *
# 2190                10             33.33
# 2191                25             50.00
# 2192               NaN               NaN
# 2193               NaN               NaN
# 2194                20             28.57
# 2195                14             21.21
# 2196                13             65.00
# 2197               NaN               NaN
# 2198                 *                 *
# 2199                16             44.44
# 2200                 8              9.76
# 2201                80             82.47
# 2202                28             70.00
# 2203                 *                 *
# 2204                 7             20.00
# 2205                57             59.38
# 2206                59             67.05
# 2207                 *                 *
# 2208                 4             18.18
# 2209                 *                 *
# 2210                 *                 *
# 2211                 8             20.51
# 2212                 *                 *
# 2213                70             82.35
# 2214                 *                 *
# 2215                 *                 *
# 2216                32             54.24
# 2217                 *                 *
# 2218                 *                 *
# 2219                 *                 *
# 2220               NaN               NaN
# 2221                93             86.92
# 2222                23             19.01
# 2223                31             51.67
# 2224                 *                 *
# 2225               111             67.27
# 2226               NaN               NaN
# 2227                 *                 *
# 2228               NaN               NaN
# 2229               NaN               NaN
# 2230                 *                 *
# 2231               NaN               NaN
# 2232                22             66.67
# 2233                 *                 *
# 2234               111             86.72
# 2235                 *                 *
# 2236                32             66.67
# 2237                24             33.80
# 2238                55             58.51
# 2239               NaN               NaN
# 2240                10              8.26
# 2241                60             92.31
# 2242                 *                 *
# 2243                20             18.18
# 2244                 *                 *
# 2245                 *                 *
# 2246                 6             17.14
# 2247                 *                 *
# 2248                34             73.91
# 2249                16             64.00
# 2250                22             43.14
# 2251                97             78.86
# 2252                38             77.55
# 2253               NaN               NaN
# 2254               NaN               NaN
# 2255               156             85.71
# 2256                 *                 *
# 2257                16             69.57
# 2258                25             34.72
# 2259                16             76.19
# 2260                17             31.48
# 2261                23             71.88
# 2262               126             86.30
# 2263                30             62.50
# 2264                60             84.51
# 2265                25             89.29
# 2266                 *                 *
# 2267               193             91.04
# 2268                10             55.56
# 2269                 *                 *
# 2270                 *                 *
# 2271                54             98.18
# 2272                98             87.50
# 2273                16             26.67
# 2274                23             76.67
# 2275                 *                 *
# 2276                20             18.87
# 2277                21             40.38
# 2278                91             82.73
# 2279                 *                 *
# 2280                 *                 *
# 2281                 *                 *
# 2282                42             76.36
# 2283                 *                 *
# 2284                10             29.41
# 2285               NaN               NaN
# 2286                47             62.67
# 2287                70             60.34
# 2288                 *                 *
# 2289                35             27.78
# 2290               153             87.93
# 2291               110             83.33
# 2292                 8             26.67
# 2293                22             37.29
# 2294                11             16.18
# 2295                75             70.75
# 2296                 *                 *
# 2297                 9             50.00
# 2298                83             79.81
# 2299                19             57.58
# 2300               NaN               NaN
# 2301               NaN               NaN
# 2302                20             52.63
# 2303                35             62.50
# 2304                 *                 *
# 2305               NaN               NaN
# 2306                40             65.57
# 2307                 *                 *
# 2308               NaN               NaN
# 2309               NaN               NaN

# %%
# we would like to investigate counties in the 25th percentile 
# use mask to generate counties where per_capita_income is lower than the 25th percentile
mask = df_groupby_county_income['per_capita_income'] < df_groupby_county_income.describe().at["25%", "per_capita_income"]
df_groupby_county_income[mask].head(3)
# Out:
#    county_name  num_of_grade12_enrollment  num_of_test_takers  \
# 10    Imperial                 611.071429          105.428571
# 12        Kern                1093.028571          105.657143
# 13       Kings                 514.400000           83.100000
#
#     num_score_grtr_21  pct_score_grtr_21  per_capita_income
# 10          38.642857          38.975000            40447.0
# 12          45.428571          42.854286            41843.0
# 13          19.700000          30.920000            39433.0

# %%
df1.dtypes
# Out:
# school_name                   object
# district_name                 object
# county_name                   object
# num_of_grade12_enrollment    float64
# num_of_test_takers           float64
# num_score_grtr_21            float64
# pct_score_grtr_21            float64
# dtype: object

# %%
sns.lmplot(x='num_of_grade12_enrollment', y='num_score_grtr_21', data=df_groupby_county_income)

# %%
df_groupby_county_income.corr()
sns.heatmap(df_groupby_county_income.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
df_groupby_county_income.head(1)
# Out:
#   county_name  num_of_grade12_enrollment  num_of_test_takers  \
# 0     Alameda                 882.163636          195.781818
#
#    num_score_grtr_21  pct_score_grtr_21  per_capita_income
# 0         133.290909          63.231273            81171.0

# %%
# Code

# ax = sns.boxplot(x = df_groupby_county_income['per_capita_income'])
ax = sns.histplot(x = df_groupby_county_income['per_capita_income'])

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %%
df_groupby_county_income.head(2)
# Out:
#   county_name  num_of_grade12_enrollment  num_of_test_takers  \
# 0     Alameda                 882.163636          195.781818
# 1      Amador                 211.250000           27.750000
#
#    num_score_grtr_21  pct_score_grtr_21  per_capita_income
# 0         133.290909          63.231273            81171.0
# 1          21.750000          78.970000            45920.0

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!

# %%
sd = {k:std_dev(list(df_groupby_county_income[k])) for (k,v) in sd.items()}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-752-2c89289fb682> in <module>
# ----> 1 sd = {k:std_dev(list(df_groupby_county_income[k])) for (k,v) in sd.items()}
#
# <ipython-input-752-2c89289fb682> in <dictcomp>(.0)
# ----> 1 sd = {k:std_dev(list(df_groupby_county_income[k])) for (k,v) in sd.items()}
#
# <ipython-input-693-da52e7c7fc4f> in std_dev(num_list)
#       3     val = 0
#       4     for num in num_list:
# ----> 5         val += (num - mean_value(num_list))**2
#       6     return (val/len(num_list))**0.5
#       7
#
# <ipython-input-692-a3e08899b5df> in mean_value(num_list)
#       3     res = 0
#       4     for num in num_list:
# ----> 5         res += num
#       6     return res/(len(num_list))
#       7
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
list(enumerate(df_groupby_county_income.columns))
# Out:
# [(0, 'county_name'),
#  (1, 'num_of_grade12_enrollment'),
#  (2, 'num_of_test_takers'),
#  (3, 'num_score_grtr_21'),
#  (4, 'pct_score_grtr_21'),
#  (5, 'per_capita_income')]
